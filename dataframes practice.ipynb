# %%
import pandas as pd

df = pd.read_csv('covid.csv')
df
# Out:
#        # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0      1             USA   98,166,904     1,084,282          NaN
# 1      2           India   44,587,307       528,629          NaN
# 2      3          France   35,342,950       155,078          NaN
# 3      4          Brazil   34,706,757       686,027          NaN
# 4      5         Germany   33,312,373       149,948          NaN
# ..   ...             ...          ...           ...          ...
# 225  226            Niue           80           NaN          NaN
# 226  227    Vatican City           29           NaN          NaN
# 227  228          Tuvalu           20           NaN          NaN
# 228  229  Western Sahara           10             1          NaN
# 229  230      MS Zaandam            9             2          NaN
#
#     Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 0         94,962,112     2,120,510              2,970            293,206
# ...

# %%
dfe=df.copy()
res=dfe.loc[dfe['Country,\nOther'] == 'Pakistan']  
res
# Out:
#      # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 52  53        Pakistan    1,572,598        30,616          3.0
#
#    Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 52        1,536,924         5,058                 47              6,853
#
#    Deaths/\n1M pop Total\nTests Tests/\n1M pop   Population
# 52             133   30,477,451        132,806  229,488,994

# %%
death=res['Total\nDeaths'].to_string()

a=death[6:]
b=int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [70], in <cell line: 4>()
#       1 death=res['Total\nDeaths'].to_string()
#       3 a=death[6:]
# ----> 4 b=int(a)
#
# ValueError: invalid literal for int() with base 10: '30,616'

# %% [markdown]
# #####

# %%
oldlist=["SHAYAN","ZAIN","HARIS","ALIYAN","SAMEER"]
newlist=["shayan","zain","haris","aliyan","sameer","saad","farjad"]


for i in newlist:
    low=i.upper()
    if low in oldlist:
        print("old")
    else:
        print("new")
# Out:
# old
# old
# old
# old
# old
# new
# new
